# %%
from bs4 import BeautifulSoup
from selenium.webdriver import ActionChains
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from datetime import date,datetime,timedelta
import time
import sys
import os
import pandas as pd

# %%
# KOBIS (일별 박스오피스) 페이지 접속하기
path = "C:\\web_driver\\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get("https://www.kobis.or.kr/kobis/business/stat/boxs/findDailyBoxOfficeList.do")
time.sleep(3)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_5684\3214305788.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
# kobis crawling

# 날짜 입력 후 조회하기
start_date = date(2020, 10, 20)
end_date = date(2022, 10, 20)

while start_date <= end_date :
    try :
        time.sleep(2)
        # 시작날짜 입력
        date_from=driver.find_element(By.XPATH,'//*[@id="sSearchFrom"]')

        for i in range(10):
            date_from.send_keys(Keys.BACKSPACE) 

        date_from.send_keys(start_date.strftime("%Y-%m-%d")) 

        # 종료날짜 입력
        date_to=driver.find_element(By.XPATH,'//*[@id="sSearchTo"]')

        for i in range(10):
            date_to.send_keys(Keys.BACKSPACE)

        date_to.send_keys(start_date.strftime("%Y-%m-%d"))
        
        # 조회 버튼 클릭
        search_btn=driver.find_element(By.XPATH,'//*[@id="searchForm"]/div/div[5]/button')
        search_btn.click()
        time.sleep(1)
        
        start_date+=timedelta(days=1)
        
        #더보기 클릭하여 전체 자료보기
        while True :
            try :
                driver.find_element(By.LINK_TEXT,"더보기").click()
            except :
                break
                       
        #전체 차트 수집하기         
        # 페이지 읽어오기       
        full_html=driver.page_source
        soup=BeautifulSoup(full_html, 'html.parser')

        # 검색날짜 
        search_date=soup.find('div','board_tit').get_text().replace("\n","")

        # 검색건수
        search_total=soup.find('em','fwb').get_text()
        print(search_total)
        
        # 컬럼 리스트 생성
        content_column=soup.find('thead').find_all('th',{'scope':'col'})

        column_list=[]
        column_list.append('일자')

        for i in content_column :
            column_list.append(i.text.replace("\t","").replace("\n","").replace("오름차순내림차순",""))
        print(column_list)
        
        # 항목 리스트 생성
        rank_table=soup.find('tbody').find_all('tr')

        rank_list=[]
        
        #리스트에 항목 담기
        for movie in rank_table :
            chart=[]
            chart.append(search_date)

            #영화 순위
            movie_rank=movie.find('td').text.replace("\t","").replace("\n","")
            chart.append(movie_rank)

            #영화제목
            movie_title=movie.find('span','ellip per90').get_text()
            chart.append(movie_title)
            
            #개봉일
            movie_chart=movie.select('td:nth-child(3)')
            for i in movie_chart :
                chart.append(i.text.replace("\n","").replace("\t","").replace(" ",""))

            #'매출액', '매출액점유율', '매출액증감(전일대비)', '누적매출액', '관객수' 등
            movie_chart=movie.find_all('td','tar')

            for i in movie_chart :
                chart.append(i.text.replace("\t","").replace("\n",""))

            rank_list.append(chart)
            
        print(rank_list)
        
         # 영화별 세부정보 수집하기
        movie_name_list=soup.find_all('span','ellip per90')
#         movie_info_tit=[]     #세부정보에 대한 컬럼은 수집하지 않음

        movie_info_cont=[]
        movie_staff=[]
        for i in movie_name_list :
            try :
                name=i.get_text()
                time.sleep(1)

                # 영화 정보 팝업 띄우기
                movie_btn=driver.find_element(By.LINK_TEXT,str(name))
                movie_btn.click()
                time.sleep(1)

                #영화 정보 가져오기
                movie_html=driver.page_source
                soup=BeautifulSoup(movie_html, 'html.parser')

                #영화제목
                movie_name=soup.find('div','hd_layer').find('strong').get_text()

#                 #영화세부정보title                     #세부정보에 대한 컬럼은 수집하지 않음
#                 movie_info1=soup.find('dl',class_='ovf cont').find_all('dt')

                #영화세부정보contents
                movie_contents=soup.find('dl',class_='ovf cont').find_all('dd')
                
#                 movie_info_tit.append("영화제목")       #세부정보에 대한 컬럼은 수집하지 않음

#                 for tit in movie_info1 :                #세부정보에 대한 컬럼은 수집하지 않음
#                     movie_info_tit.append(tit.text.replace("\n","").replace("\t",""))
                
                movie_info=[]
                movie_info.append(movie_name)
            
                for cont in movie_contents :
                    movie_info.append(cont.text.replace("\n","").replace("\t","").replace(" ","").strip())
                
                movie_info_cont.append(movie_info)
                
                #감독, 배우 정보 수집
                try : 
                    movie_staff_dict={'감독' : [],'배우' : []}

                    director=soup.find('div','staffMore').find('dd').text.strip()
                    movie_staff_dict['감독'].append(director)

                    actor_list=soup.find('div','staffMore').find('td').find_all('a')

                    for i in actor_list :
                        movie_staff_dict['배우'].append(i.text.strip())
                        
                except : 
                    movie_staff_dict={'감독' : [],'배우' : []}
                    
                movie_staff.append(movie_staff_dict)

                # 팝업 창 닫기
                time.sleep(1)
                driver.find_element(By.LINK_TEXT,"뒤로").click()
                
            except : 
                print("오류 항목을 제외합니다.")
                continue
                
        print(movie_info_cont)
        print(movie_staff)
            
    except :
        print("데이터를 수집하지 못하였습니다.")
        break
# Out:
# 108
# ['일자', '순위', '영화명', '개봉일', '매출액', '매출액점유율', '매출액증감(전일대비)', '누적매출액', '관객수', '관객수증감(전일대비)', '누적관객수', '스크린수', '상영횟수']
# [['2020년 10월 20일(화)', '1', '소리도 없이', '2020-10-15', '171,664,030', '35.9%', '-12,431,810(-6.8%)', '2,331,008,630', '20,730', '-1,275(-5.8%)', '263,168', '1,000', '3,378'], ['2020년 10월 20일(화)', '2', '담보', '2020-09-29', '119,240,190', '24.9%', '-7,156,030(-5.7%)', '12,779,963,140', '14,600', '-494(-3.3%)', '1,478,480', '935', '2,694'], ['2020년 10월 20일(화)', '3', '테넷', '2020-08-26', '27,094,680', '5.7%', '1,498,310(5.9%)', '17,684,765,980', '3,021', '217(7.7%)', '1,917,434', '297', '471'], ['2020년 10월 20일(화)', '4', '삼진그룹 영어토익반', '2020-10-21', '12,858,000', '2.7%', '7,477,000(139.0%)', '56,286,000', '2,587', '1,253(93.9%)', '8,787', '22', '22'], ['2020년 10월 20일(화)', '5', '그대, 고맙소 : 김호중 생애 첫 팬미팅 무비', '2020-09-29', '59,025,500', '12.3%', '13,318,000(29.1%)', '2,800,026,500', '1,993', '428(27.3%)', '90,821', '93', '157'], ['2020년 10월 20일(화)', '6', '돌멩이', '2020-10-15', '9,490,010', '2.0%', '926,610(10.8%)', '118,477,360', '1,204', '111(10.2%)', '14,008', '327', '526'], ['2020년 10월 20일(화)', '7', '언힌지드', '2020-10-07', '8,918,640', '1.9%', '-582,290(-6.1%)', '992,711,120', '1,067', '-76(-6.6%)', '114,823', '282', '394'], ['2020년 10월 20일(화)', '8', '폰조', '2020-10-14', '7,955,370', '1.7%', '-805,630(-9.2%)', '191,810,020', '1,015', '-89(-8.1%)', '23,188', '304', '508'], ['2020년 10월 20일(화)', '9', '그린랜드', '2020-09-29', '7,178,750', '1.5%', '-1,406,120(-16.4%)', '2,752,588,750', '876', '-187(-17.6%)', '321,680', '230', '282'], ['2020년 10월 20일(화)', '10', '국제수사', '2020-09-29', '5,569,800', '1.2%', '948,830(20.5%)', '4,477,261,320', '705', '142(25.2%)', '534,270', '170', '206'], ['2020년 10월 20일(화)', '11', '기기괴괴 성형수', '2020-09-09', '3,520,000', '0.7%', '-10,000(-0.3%)', '852,329,400', '702', '-1(-0.1%)', '100,089', '4', '4'], ['2020년 10월 20일(화)', '12', '어디갔어, 버나뎃', '2020-10-08', '5,467,000', '1.1%', '1,103,500(25.3%)', '225,532,500', '675', '134(24.8%)', '26,176', '129', '189'], ['2020년 10월 20일(화)', '13', '애프터: 그 후', '2020-10-07', '3,877,970', '0.8%', '789,350(25.6%)', '288,834,920', '485', '104(27.3%)', '34,224', '92', '119'], ['2020년 10월 20일(화)', '14', '남과 여: 여전히 찬란한', '2020-10-15', '3,090,400', '0.6%', '178,700(6.1%)', '28,319,500', '394', '5(1.3%)', '3,313', '61', '75'], ['2020년 10월 20일(화)', '15', '밥정', '2020-10-07', '2,412,300', '0.5%', '593,000(32.6%)', '86,712,890', '356', '76(27.1%)', '11,087', '60', '70'], ['2020년 10월 20일(화)', '16', '극장판 요괴워치: 포에버 프렌즈', '2020-10-15', '2,336,100', '0.5%', '-193,100(-7.6%)', '77,790,470', '329', '-2(-0.6%)', '9,818', '112', '121'], ['2020년 10월 20일(화)', '17', '담쟁이', '2020-10-28', '2,244,000', '0.5%', '2,244,000(100.0%)', '4,075,000', '247', '247(100.0%)', '451', '3', '3'], ['2020년 10월 20일(화)', '18', '부활: 그 증거', '2020-10-08', '1,884,000', '0.4%', '398,100(26.8%)', '73,756,770', '220', '49(28.7%)', '8,380', '29', '35'], ['2020년 10월 20일(화)', '19', '브레이크 더 사일런스: 더 무비', '2020-09-24', '1,902,500', '0.4%', '170,500(9.8%)', '1,129,157,500', '219', '22(11.2%)', '128,213', '61', '69'], ['2020년 10월 20일(화)', '20', '프록시마 프로젝트', '2020-10-15', '1,578,500', '0.3%', '-87,300(-5.2%)', '25,389,940', '217', '0(0.0%)', '2,870', '64', '79'], ['2020년 10월 20일(화)', '21', '종이꽃', '2020-10-22', '1,827,000', '0.4%', '99,000(5.7%)', '6,192,000', '203', '11(5.7%)', '704', '1', '1'], ['2020년 10월 20일(화)', '22', '아웃포스트', '2020-09-23', '703,500', '0.1%', '222,600(46.3%)', '425,750,870', '189', '40(26.8%)', '50,853', '6', '8'], ['2020년 10월 20일(화)', '23', '교실 안의 야크', '2020-09-30', '1,442,400', '0.3%', '594,000(70.0%)', '53,245,040', '184', '77(72.0%)', '6,337', '22', '27'], ['2020년 10월 20일(화)', '24', '안녕까지 30분', '2020-10-14', '1,466,000', '0.3%', '43,800(3.1%)', '26,390,400', '178', '-1(-0.6%)', '3,194', '71', '101'], ['2020년 10월 20일(화)', '25', '그리드', '2020-10-15', '1,364,500', '0.3%', '210,700(18.3%)', '17,850,500', '176', '26(17.3%)', '2,050', '53', '62'], ['2020년 10월 20일(화)', '26', '알피니스트 - 어느 카메라맨의 고백 ', '2020-10-15', '1,095,000', '0.2%', '309,530(39.4%)', '12,529,010', '151', '43(39.8%)', '1,621', '19', '22'], ['2020년 10월 20일(화)', '27', '극장판 ...
# 106 순위 오류 항목을 제외합니다.
# 106 순위 오류 항목을 제외합니다.
# 106 순위 오류 항목을 제외합니다.
# [['소리도 없이', '20194424', '해당정보없음', '해당정보없음', '장편|일반영화|범죄,드라마|99분11초|15세이상관람가|한국', '2020-10-15', '2020년', '개봉', '2019-07-29~2019-10-31', '해당정보없음', '2D:디지털(20194424D)'], ['담보', '20199816', '해당정보없음', '해당정보없음', '장편|일반영화|드라마|113분0초|12세이상관람가|한국', '휴먼드라마', '2020-09-29', '2020년', '개봉', '2019-04-22~2019-07-31', '해당정보없음', '2D:디지털(20199816D),디지털가치봄(20199816L)'], ['테넷', '20201122', '해당정보없음', '해당정보없음', '장편|일반영화|액션,SF|149분59초|12세이상관람가|미국', '멀티장르액션블록버스터', '2020-08-26', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20201122D)4D:4D(20201122F)IMAX:IMAX(20201122I)DOLBYCINEMA:DOLBYCINEMA(202011226)'], ['삼진그룹 영어토익반', '20197121', '해당정보없음', '해당정보없음', '장편|일반영화|드라마|110분18초|12세이상관람가|한국', '2020-10-21', '2020년', '개봉', '2019-10-26~2020-01-22', '해당정보없음', '2D:디지털(20197121D),디지털가치봄(20197121L)'], ['그대, 고맙소 : 김호중 생애 첫 팬미팅 무비', '20206826', '해당정보없음', '해당정보없음', '장편|일반영화|공연|80분32초|전체관람가|한국', '2020-09-29', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20206826D)'], ['돌멩이', '20181162', '해당정보없음', '해당정보없음', '장편|예술,독립영화|드라마|106분48초|12세이상관람가|한국', '2020-10-15', '2018년', '개봉', '2017-10~2017-12', '해당정보없음', '2D:디지털(20181162D),디지털가치봄(20181162L)'], ['언힌지드', '20202684', '해당정보없음', '해당정보없음', '장편|일반영화|스릴러,범죄|90분19초|청소년관람불가|미국', '2020-10-07', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20202684D)'], ['폰조', '20183583', '해당정보없음', '(Capone)', '장편|예술영화|범죄,드라마|103분41초|청소년관람불가|미국', '2020-10-14', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20183583D)'], ['그린랜드', '20204008', '해당정보없음', '해당정보없음', '장편|일반영화|액션,스릴러|119분52초|12세이상관람가|미국', '2020-09-29', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20204008D)4D:4D(20204008F)'], ['국제수사', '20184482', '해당정보없음', '패키지', '장편|일반영화|코미디,액션|105분50초|15세이상관람가|한국', '2020-09-29', '2020년', '개봉', '2018-05-29~2018-09-20', '해당정보없음', '2D:디지털(20184482D)'], ['기기괴괴 성형수', '20201687', '해당정보없음', '해당정보없음', '장편|예술영화|공포(호러),스릴러|85분23초|15세이상관람가|한국', '호러성형괴담', '2020-09-09', '2020년', '개봉', '2020-11-18', '해당정보없음', '해당정보없음', '2D:디지털(20201687D)4D:4D(20201687F)'], ['어디갔어, 버나뎃', '20206362', '해당정보없음', '해당정보없음', '장편|예술영화|코미디,드라마|109분11초|12세이상관람가|미국', '2020-10-08', '2019년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20206362D)'], ['애프터: 그 후', '20202502', '해당정보없음', '애프터그후,애프터2(After2)', '장편|일반영화|멜로/로맨스,드라마|105분9초|15세이상관람가|미국', '빨간맛삼각로맨스', '2020-10-07', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20202502D)'], ['남과 여: 여전히 찬란한', '20206241', '해당정보없음', "더베스트이어스오브어라이프(Lesplusbellesanneesd'unevie)", '장편|예술영화|드라마,멜로/로맨스|90분33초|15세이상관람가|프랑스', '2020-10-15', '2019년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20206241D)'], ['밥정', '20199815', '해당정보없음', '108접시,원더링쉐프(TheWanderingChef-108plates)', '장편|예술,독립영화|다큐멘터리,드라마|82분17초|전체관람가|한국', '2020-10-07', '2019년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20199815D),디지털가치봄(20199815L)'], ['극장판 요괴워치: 포에버 프렌즈', '20208393', '해당정보없음', '(Yo-KaiWatch:FOREVERFRIENDS,Yo-KaiWatchtheMovie5:FOREVERFRIENDS)', '장편|일반영화|애니메이션|99분51초|전체관람가|일본', '2020-10-15', '2019년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20208393D),디지털더빙(20208393T)'], ['담쟁이', '20209946', '해당정보없음', '해당정보없음', '장편|예술,독립영화|가족,드라마|99분48초|15세이상관람가|한국', '2020-10-28', '2020년', '개봉', '2019-05-12~2019-06-21', '해당정보없음', '2D:디지털(20209946D),디지털영문자막(20209946E)'], ['부활: 그 증거', '20200246', '해당정보없음', '해당정보없음', '장편|예술영화|다큐멘터리|96분33초|전체관람가|한국', '2020-10-08', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20200246D)'], ['브레이크 더 사일런스: 더 무비', '20204684', '해당정보없음', '해당정보없음', '장편|일반영화|다큐멘터리|89분23초|전체관람가|한국', '2020-09-24', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20204684D)'], ['프록시마 프로젝트', '20206822', '해당정보없음', '해당정보없음', '장편|예술영화|드라마|107분21초|12세이상관람가|프랑스', '스페이스드라마', '2020-10-15', '2019년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20206822D)'], ['종이꽃', '20196676', '해당정보없음', '해당정보없음', '장편|예술,독립영화|드라마|103분0초|12세이상관람가|한국', '2020-10-22', '2019년', '개봉', '2019-03-14~2019-04-13', '해당정보없음', '2D:디지털(20196676D),디지털영문자막(20196676E)'], ['아웃포스트', '20202341', '해당정보없음', '디아웃포스트', '장편|일반영화|전쟁,드라마|123분22초|15세이상관람가|미국', '전쟁실화', '2020-09-23', '2020년', '개봉', '해당정보없음', '해당정보없음', '2D:디지털(20202341D)'], ['교실 안의 야크', '20204990', '해당정보없음', '해당정보없음', '장편|예술영화|드라마|109분26초|전체관람가|기타', '2020-09-30', '2019년', ' ...
# [{'감독': ['홍의정'], '배우': ['유아인(태인)', '유재명(창복)']}, {'감독': ['강대규'], '배우': ['성동일(두석)', '하지원(성인 승이)', '김희원(종배)', '박소이(어린 승이 역)']}, {'감독': ['크리스토퍼 놀란'], '배우': ['존 데이비드 워싱턴', '로버트 패틴슨', '엘리자베스 데비키', '애론 테일러 존슨']}, {'감독': ['이종필'], '배우': ['고아성', '이솜', '박혜수(심보람)']}, {'감독': ['[주연] 김호중'], '배우': ['김호중']}, {'감독': ['김정식'], '배우': ['김대명(윤석구)', '송윤아(김선생)', '김의성(노신부)', '전채은(장은지)']}, {'감독': ['데릭 보트'], '배우': ['러셀 크로우(더 맨)', '카렌 피스토리우스(레이첼)', '가브리엘 베이트먼(카일)']}, {'감독': ['조쉬 트랭크'], '배우': ['톰 하디', '린다 카델리니', '잭 로던', '맷 딜런']}, {'감독': ['릭 로먼 워'], '배우': ['제라드 버틀러', '모레나 바카린']}, {'감독': ['김봉한'], '배우': ['곽도원(홍병수)', '김대명(황만철)', '김희원(패트릭)', '김상호(용배)']}, {'감독': ['조경훈'], '배우': ['문남숙(예지)', '장민혁(지훈)', '조현정(시술사)', '김보영(미리)', '최승훈(매니저)']}, {'감독': ['리차드 링클레이터'], '배우': ['케이트 블란쳇', '빌리 크루덥']}, {'감독': ['로저 컴블'], '배우': ['히어로 파인즈 티핀(하딘)', '조세핀 랭포드(테사)', '딜런 스프라우즈(트레버)']}, {'감독': ['끌로드 를르슈'], '배우': ['장-루이 트린티냥(장-루이)', '아누크 에메(안느)']}, {'감독': ['박혜령'], '배우': ['임지호', '김순규']}, {'감독': ['타카하시 시게하루'], '배우': ['신용우(고귀한)', '정혜원(서민)', '박리나(천송이)', '김현지(깜냥이)']}, {'감독': ['한제이'], '배우': ['우미화(정은수)', '이연(김예원)', '김보민(김수민)']}, {'감독': ['김상철'], '배우': ['권오중(권오중)', '이성혜', '이용규', '이어령', '천정은']}, {'감독': ['박준수'], '배우': ['김남준', '김석진', '민윤기', '정호석', '박지민', '김태형', '전정국']}, {'감독': ['앨리스 위노코'], '배우': ['에바 그린', '맷 딜런']}, {'감독': ['고훈'], '배우': ['안성기(윤성길)', '유진(고은숙)', '김혜성(윤지혁)', '장재희(강노을)']}, {'감독': ['로드 루리'], '배우': ['스콧 이스트우드', '케일럽 랜드리 존스', '올랜도 블룸']}, {'감독': [], '배우': []}, {'감독': ['[주연] 키타무라 타쿠미'], '배우': ['키타무라 타쿠미']}, {'감독': ['마이클 윈터바텀'], '배우': ['스티브 쿠건', '아일라 피셔', '에이사 버터필드']}, {'감독': ['유야마 쿠니히코|사카키바라 모토노리'], '배우': ['이선호(지우)', '홍시호(뮤츠)']}, {'감독': ['정세교'], '배우': ['나문희(오문희)', '이희준(두원)', '김예은(한재숙)']}, {'감독': ['빅터 플레밍'], '배우': ['잉그리드 버그만']}, {'감독': ['이영준'], '배우': ['엄상현(볼트)', '양정화(볼트)', '이소영(루시)', '전태열(새미)', '신용우(맥스)']}, {'감독': ['라이너 홀제메르'], '배우': ['마틴 마르지엘라', '장 폴 고티에', '카린 로이펠드']}, {'감독': [], '배우': []}, {'감독': ['애슐리 해밀턴'], '배우': ['린 샤예']}, {'감독': [], '배우': []}, {'감독': ['와타나베 아유무'], '배우': ['아시다 마나(루카)', '이시바시 히이로(우미)', '우라가미 세이슈(소라)', '모리사키 윈(앙글라드)']}, {'감독': [], '배우': []}, {'감독': [], '배우': []}, {'감독': ['김미례'], '배우': ['김미례']}, {'감독': [], '배우': []}, {'감독': ['조지 쿠커'], '배우': ['찰스 보이어', '잉그리드 버그만', '조셉 코튼']}, {'감독': ['최재훈'], '배우': ['장혁(태율)', '김현수(태옥)', '조 타슬림(구루타이)']}, {'감독': ['아론 소킨'], '배우': ['사챠 바론 코헨', '에디 레드메인', '야히아 압둘 마틴 2세', '마크 라이런스', '조셉 고든 레빗', '마이클 키튼', '프랭크 란젤라', '존 캐롤 린치']}, {'감독': ['허동우'], '배우': ['전소민(서리애)', '최정원(모철우)', '김정균(리애삼촌)', '김동주(리애모)']}, {'감독': ['김미례'], '배우': ['유영선(글 구성)', '김미례(글 구성)']}, {'감독': ['신카이 마코토'], '배우': ['하기와라 마사토(시라카와 타쿠야 역)', '난리 유카(사와타리 사유리 역)', '요시오카 히데타카(후지사와 히로키 역)']}, {'감독': ['신카이 마코토'], '배우': ['미즈하시 켄지']}, {'감독': ['알프레드 히치콕'], '배우': ['캐리 그랜트(T.R. 데블린)', '잉그리드 버그만(알리시아 휴버먼)']}, {'감독': ['니키 카로'], '배우': ['유역비', '이연걸', '공리', '견자단', '제이슨 스콧 리']}, {'감독': ['윤단비'], '배우': ['박현영', '양흥주', '최정운', '박승준', '강석원(요양보호사)']}, {'감독': ['신정원'], '배우': ['이정현(소희)', '김성오(만길)', '서영희(세라)', '양동근(소장)', '이미도(양선)']}, {'감독': ['아나톨 리트박'], '배우': ['데보라 카(다이아나 애쉬모어)', '율 브린너(슈로프)']}, {'감독': [], '배우': []}, {'감독': ['세실 B. 데밀'], '배우': ['안젤라 랜스베리', '헤디 라머', '조지 샌더스']}, {'감독': ['돈 밀러'], '배우': ['페르난도 보테로']}, {'감독': ['데이빗 린'], '배우': ['셀리아 존슨', '트레버 하워드']}, {'감독': ['홍상수'], '배우': ['김민희(감희)', '서영화', '송선미', '김새벽', '권해효', '강이서(면접여자)']}, {'감독': ['버드 보에티처'], '배우': ['조이 페이지', '길버트 롤랜드']}, {'감독': ['헨리 킹'], '배우': ['고든 맥라', '셜리 존스', '카메론 미첼']}, {'감독': ['신카이 마코토'], '배우': ['다이고 코타로', '모리 나나', '오구리 슌', '심규혁', '최한', '강은애', '김서영']}, {'감독': ['양우석'], '배우': ['정우성', '곽도원', '유연석', '앵거스 맥페이든']}, {'감독': ['자비에 돌란'], '배우': ['앤 도벌', '안토니-올리버 피론', '수잔 클레망']}, {'감독': ['노아 바움백'], '배우': ['그레타 거윅(프란시스)', '믹키 섬너(소피)', '그레이스 검머(레이첼)', '아담 드라이버(레브)']}, {'감독': ['피에트로 마르첼로'], '배우': ['루카 마리넬리']}, {'감독': ['프레드 진네만'], '배우': ['게리 쿠퍼', '토마스 미첼', '그레이스 켈리']}, {'감독': ['정형민'], '배우': ['정명숙']}, {'감독': ['신카이 마코토'], '배우': ['카미키 류노스케(타치바나 타키 역)', '카미시라이시 모네(미야미즈 미츠하 역)', '나가사와 마사미(오쿠데라 미키 역)', '이치하라 에수코(미야미즈 히토하 역)', '유키 아오이(나토리 사야카 역)', '시마자키 노부나가(후지이 츠카사 역)', '이시카와 카이토(타카기 신타 역)', '타니 카논(미야미즈 요츠하 역)']}, {'감독': ['시바타 히로키'], '배우': ['김은아(엉덩이 탐정)', '소연(브라운)', '홍진 ...
# 123
# ['일자', '순위', '영화명', '개봉일', '매출액', '매출액점유율', '매출액증감(전일대비)', '누적매출액', '관객수', '관객수증감(전일대비)', '누적관객수', '스크린수', '상영횟수']
# [['2020년 10월 21일(수)', '1', '삼진그룹 영어토익반', '2020-10-21', '296,315,120', '46.6%', '283,457,120(2,204.5%)', '352,601,120', '37,412', '34,825(1,346.2%)', '46,199', '1,615', '5,869'], ['2020년 10월 21일(수)', '2', '소리도 없이', '2020-10-15', '128,576,980', '20.2%', '-43,087,050(-25.1%)', '2,459,585,610', '15,500', '-5,230(-25.2%)', '278,668', '671', '1,998'], ['2020년 10월 21일(수)', '3', '담보', '2020-09-29', '100,753,460', '15.8%', '-18,486,730(-15.5%)', '12,880,716,600', '12,676', '-1,924(-13.2%)', '1,491,156', '618', '1,727'], ['2020년 10월 21일(수)', '4', '테넷', '2020-08-26', '22,876,620', '3.6%', '-4,218,060(-15.6%)', '17,707,642,600', '2,481', '-540(-17.9%)', '1,919,915', '213', '333'], ['2020년 10월 21일(수)', '5', '에브리타임 아이 다이', '2020-10-21', '8,368,900', '1.3%', '8,368,900(100.0%)', '8,809,900', '1,061', '1,061(100.0%)', '1,110', '140', '211'], ['2020년 10월 21일(수)', '6', '기기괴괴 성형수', '2020-09-09', '3,550,000', '0.6%', '30,000(0.9%)', '855,879,400', '705', '3(0.4%)', '100,794', '4', '5'], ['2020년 10월 21일(수)', '7', '돌멩이', '2020-10-15', '5,280,600', '0.8%', '-4,209,410(-44.4%)', '123,757,960', '672', '-532(-44.2%)', '14,680', '205', '240'], ['2020년 10월 21일(수)', '8', '21 브릿지: 테러 셧다운 ', '2020-01-01', '4,938,270', '0.8%', '4,938,270(100.0%)', '781,282,970', '627', '627(100.0%)', '100,870', '93', '137'], ['2020년 10월 21일(수)', '9', '폰조', '2020-10-14', '3,280,900', '0.5%', '-4,674,470(-58.8%)', '195,090,920', '411', '-604(-59.5%)', '23,599', '105', '130'], ['2020년 10월 21일(수)', '10', '그대, 고맙소 : 김호중 생애 첫 팬미팅 무비', '2020-09-29', '12,513,000', '2.0%', '-46,512,500(-78.8%)', '2,812,539,500', '405', '-1,588(-79.7%)', '91,226', '49', '62'], ['2020년 10월 21일(수)', '11', '극장판 요괴워치: 포에버 프렌즈', '2020-10-15', '2,496,600', '0.4%', '160,500(6.9%)', '80,287,070', '349', '20(6.1%)', '10,167', '84', '90'], ['2020년 10월 21일(수)', '12', '남과 여: 여전히 찬란한', '2020-10-15', '2,606,100', '0.4%', '-484,300(-15.7%)', '30,925,600', '347', '-47(-11.9%)', '3,660', '52', '61'], ['2020년 10월 21일(수)', '13', '언힌지드', '2020-10-07', '2,786,000', '0.4%', '-6,132,640(-68.8%)', '995,497,120', '329', '-738(-69.2%)', '115,152', '84', '102'], ['2020년 10월 21일(수)', '14', '그린랜드', '2020-09-29', '2,492,370', '0.4%', '-4,686,380(-65.3%)', '2,755,081,120', '308', '-568(-64.8%)', '321,988', '43', '58'], ['2020년 10월 21일(수)', '15', '밥정', '2020-10-07', '1,782,500', '0.3%', '-629,800(-26.1%)', '88,495,390', '277', '-79(-22.2%)', '11,364', '35', '45'], ['2020년 10월 21일(수)', '16', '극장판 포켓몬스터 뮤츠의 역습 EVOLUTION', '2020-09-30', '2,490,000', '0.4%', '1,504,400(152.6%)', '731,969,350', '259', '127(96.2%)', '91,229', '18', '19'], ['2020년 10월 21일(수)', '17', '브레이크 더 사일런스: 더 무비', '2020-09-24', '2,190,000', '0.3%', '287,500(15.1%)', '1,131,347,500', '256', '37(16.9%)', '128,469', '60', '67'], ['2020년 10월 21일(수)', '17', '어디갔어, 버나뎃', '2020-10-08', '2,009,500', '0.3%', '-3,457,500(-63.2%)', '227,542,000', '256', '-419(-62.1%)', '26,432', '32', '44'], ['2020년 10월 21일(수)', '19', '여기가 천국', '', '1,145,000', '0.2%', '1,145,000(100.0%)', '1,349,000', '229', '229(100.0%)', '433', '1', '1'], ['2020년 10월 21일(수)', '20', '애프터: 그 후', '2020-10-07', '1,635,940', '0.3%', '-2,242,030(-57.8%)', '290,470,860', '199', '-286(-59.0%)', '34,423', '27', '30'], ['2020년 10월 21일(수)', '20', '프록시마 프로젝트', '2020-10-15', '1,499,000', '0.2%', '-79,500(-5.0%)', '26,888,940', '199', '-18(-8.3%)', '3,069', '38', '49'], ['2020년 10월 21일(수)', '22', '웰컴 투 X-월드', '2020-10-29', '1,631,000', '0.3%', '1,631,000(100.0%)', '2,731,000', '193', '193(100.0%)', '353', '2', '2'], ['2020년 10월 21일(수)', '23', '원더풀 데이즈', '2003-07-17', '1,719,000', '0.3%', '1,719,000(100.0%)', '1,719,000', '191', '191(100.0%)', '191', '2', '2'], ['2020년 10월 21일(수)', '24', '젊은이의 양지', '2020-10-28', '1,692,000', '0.3%', '1,692,000(100.0%)', '2,406,000', '188', '188(100.0%)', '290', '1', '1'], ['2020년 10월 21일(수)', '25', '교실 안의 야크', '2020-09-30', '1,285,500', '0.2%', '-156,900(-10.9%)', '54,530,540', '170', '-14(-7.6%)', '6,507', '23', '25'], ['2020년 10월 21일(수)', '26', '페뷸러스', '2020-11-05', '1,078,000', '0.2%',  ...
