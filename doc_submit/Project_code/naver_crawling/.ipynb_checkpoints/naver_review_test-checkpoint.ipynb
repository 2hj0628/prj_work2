# %%
import selenium
from selenium import webdriver
from selenium.webdriver.common.by import By
# from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.service import Service
from bs4 import BeautifulSoup
import time
import pandas as pd
import xlwt
import os
from selenium.webdriver.chrome.options import Options
# import chromedriver_autoinstaller
import subprocess

# %%
##디버거 크롬
datadir=os.getcwd()+r'\chrometemp'    
try:
    subprocess.Popen(r'C:\Program Files\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="'+datadir+r'"') 
except:
    subprocess.Popen(r'C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --remote-debugging-port=9222 --user-data-dir="'+datadir+r'"')
option=Options()
option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")

#크롬 버전확인하여 chromedriver 설치하고 구동
chrome_ver=chromedriver_autoinstaller.get_chrome_version().split('.')[0]
try:
    driver=webdriver.Chrome(service=Service(f'./{chrome_ver}/chromedriver.exe'), options=option)
except:
    chromedriver_autoinstaller.install(True)
    driver=webdriver.Chrome(service=Service(f'./{chrome_ver}/chromedriver.exe'), options=option)
#html페이지소스 전체로딩후 연결, 최대10초 대기
driver.implicitly_wait(10)
#크롤링할 페이지 연결
url="https://movie.naver.com/movie/point/af/list.naver"
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <cell line: 11>()
#       8 option.add_experimental_option("debuggerAddress", "127.0.0.1:9222")
#      10 #크롬 버전확인하여 chromedriver 설치하고 구동
# ---> 11 chrome_ver=chromedriver_autoinstaller.get_chrome_version().split('.')[0]
#      12 try:
#      13     driver=webdriver.Chrome(service=Service(f'./{chrome_ver}/chromedriver.exe'), options=option)
#
# NameError: name 'chromedriver_autoinstaller' is not defined

# %%
# KOBIS (일별 박스오피스) 페이지 접속하기
path = "C:\\web_driver\\chromedriver.exe"
driver = webdriver.Chrome(path)
driver.get("https://movie.naver.com/movie/point/af/list.naver")
time.sleep(3)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_21416\3859343614.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path)

# %%
print("<네이버 영화리뷰 크롤링을 시작합니다.>")
print()
full_html=driver.page_source    
soup=BeautifulSoup(full_html,'html.parser')

##게시물 수
content_num=soup.find_all('div','h5_right_txt')

for i in content_num:
    txt2=i.get_text().strip()
print(txt2)


#추출데이터 누적할 변수
movie_num_txt=[]
movie_name_txt=[]
review_txt=[]
list_netizen_score_txt=[]
whole_score_txt=[]
date_txt=[]


num=0
# Out:
# <네이버 영화리뷰 크롤링을 시작합니다.>
#
# 총 14,349,183개의 평점이 있습니다.

# %%
#데이터 추출
for page in range(1,2):
        
    
    full_html=driver.page_source    
    soup=BeautifulSoup(full_html,'html.parser')

    ##리뷰 번호
    movie_num=soup.find_all('td','ac num')

    for i in movie_num:
        txt=i.get_text().strip()
        num+=1
        movie_num_txt.append(txt)
    print(movie_num_txt)

    ##영화 이름
    movie_name=soup.find_all('a','movie color_b')

    for i in movie_name:
        txt=i.get_text().strip()
        num+=1
        movie_name_txt.append(txt)
    print(movie_name_txt)

    ##리뷰    
    reviews = soup.find_all("td",{"class":"title"})
    for i in reviews:
        sentence = i.find("a",{"class":"report"}).get("onclick").split("', '")[2]
        #만약 리뷰 내용이 비어있다면 데이터를 사용하지 않음
        if sentence != "":
            review_txt.append([sentence])
    print(review_txt)

    ##별점
    list_netizen_score=soup.find_all('div','list_netizen_score')

    for i in list_netizen_score:
        txt=i.get_text().strip()
        new_txt = txt.replace('별점 - 총 10점 중', '')
        num+=1
        list_netizen_score_txt.append(new_txt)
    print(list_netizen_score_txt)

    ##총 별점
    whole_score='10'
    for i in list_netizen_score:
        num+=1
        whole_score_txt.append(whole_score)
    print(whole_score_txt)

    
    ##글쓴이+날짜
    writer_date=soup.find_all('td','num')
    writer_date_list=[]
    for i in writer_date :
        date_list.append(i)
    print(date_list)
    
    
    ##글쓴이
    writer=soup.find_all('a','author')
    writer_list=[]
    for i in writer :
        writer_list.append(i.get_text())
    print(writer_list)
    
    
    ##날짜만
    
#     ##페이지 넘기기
#     page+=1    
#     driver.find_element(By.LINK_TEXT, str(page)).send_keys(Keys.ENTER)        

#     time.sleep(3)
# Out:
# ['18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470', '18507479', '18507478', '18507477', '18507476', '18507475', '18507474', '18507473', '18507472', '18507471', '18507470']
# ['블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '블랙 아담', '블랙 아담', '20세기 소녀', '반지의 제왕: 반지 원정대', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스', '탐정: 리턴즈', '에브리씽 에브리웨어 올 앳 원스', '20세기 소녀', '에브리씽 에브리웨어 올 앳 원스']
# [['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다인생영화 목록에 슬쩍....'], ['몇 번을 봐도 재밌어요권상우 배우님은 저런 역할이 찰떡인 것 같아요'], ['아이맥스 재개봉 좀 해주라 제발ㅠ 한번 더 봐야된다'], ['감독이 좋은쪽으로 미친게 틀림없다.'], ['요즘 마블 보다 재미있는것 같음'], ['호불호 갈릴듯 음...뭐라할까 '], ['갬동앤드 맘이 몽클몽클'], ['와,, 그저 갓작이라고밖에 못합니다 ...
# ['10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10', '10', '4', '10', '10', '10', '10', '10', '10', '10', '10']
# ['10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10', '10']
# ['nata****', 'tlzm****', 'naee****', 'yuna****', 'yun4****', 'bii0****', 'elxn****', '1206****', 'ssgh****', '2big****']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [34], in <cell line: 2>()
#      70 num=1
#      71 for i in range(1,11):
# ---> 72     date=soup.find('td').find_element(By.XPATH,'//*[@id="old_content"]/table/tbody/tr[{num}]/td[3]/text()')
#      73     print(date)
#      74     num+=1
#
# TypeError: 'NoneType' object is not callable

# %%
full_html=driver.page_source    
soup=BeautifulSoup(full_html,'html.parser')

total=soup.find('tbody').find_all('tr')
# print(total)

total_list=[]
for i in range(1,11) : 
    for review in total :
        chart=[]

        #번호
        review_num=review.find('td','ac num').get_text()
        chart.append(review_num)

        #영화제목
        movie_name=review.find('a','movie color_b').get_text()
        chart.append(movie_name)

        #별점
        review_score=review.find('div','list_netizen_score').find('em').get_text()
        chart.append(review_score)

        #감상평
        review_txt=review.find('td','title').get_text()
        chart.append(review_txt)

        #글쓴이
        writer=review.find('a','author').get_text()
        chart.append(writer)

        #작성일
#         date=review.find('td','num').get_text()
#         chart.append(date)

        total_list.append(chart)
        
print(total_list)
# Out:
# [['18507576', '늑대사냥', '1', '\n늑대사냥\n\n별점 - 총 10점 중1\n\n오랜만에 본 정말 기계 쪽이나  의학 쪽 전개 전부 개똥같았던 영화 ?드라마도 이보단 나았겠다 억지 억지 이런 억지가 어디 또 있을까 오래전 부터 상업영화 관객은 돈벌이 수단이었지만 그 돈을 벌려면 관객들 수준을 압도하는 그런 영상을 만들어야지 눈가리고 아웅 돈만 벌면 그만이다 했던 시절은 이제 갔어요 이젠 감독 보다 관객이 더 하이 레벨이란 걸 알아야지 .... \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'hdc5****'], ['18507575', '에브리씽 에브리웨어 올 앳 원스', '10', '\n에브리씽 에브리웨어 올 앳 원스\n\n별점 - 총 10점 중10\n\n영화를 보고 장르 그자체에 신선함을 느낀건 정말 오랜만이다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'rose****'], ['18507574', '상견니', '10', '\n상견니\n\n별점 - 총 10점 중10\n\n리쯔웨이, 모쥔제, 황위쉬안 다 워아이니 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'kja6****'], ['18507573', '고고다이노 극장판: 얼음공룡의 비밀', '10', '\n고고다이노 극장판: 얼음공룡의 비밀\n\n별점 - 총 10점 중10\n\n영화 잘 봤습니다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'pook****'], ['18507572', '귀못', '8', '\n귀못\n\n별점 - 총 10점 중8\n\n오랜만의 한국적 공포영화라 반가웠다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'stev****'], ['18507571', '에브리씽 에브리웨어 올 앳 원스', '10', '\n에브리씽 에브리웨어 올 앳 원스\n\n별점 - 총 10점 중10\n\n인생을 살면서 본 모든 영화중에서 가장 미친 영화 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'kjh8****'], ['18507570', '프로메어', '10', '\n프로메어\n\n별점 - 총 10점 중10\n\n영화 잘 봤어요.. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'pook****'], ['18507569', '블랙 아담', '8', '\n블랙 아담\n\n별점 - 총 10점 중8\n\n무난하게 잘 봤습니다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'hyun****'], ['18507568', '블랙 아담', '8', '\n블랙 아담\n\n별점 - 총 10점 중8\n\n이정도면 볼만함 꼬맹이 목소리때문에몰입 깨지는거 빼고는 좋았으 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'sks0****'], ['18507567', '인생은 아름다워', '7', '\n인생은 아름다워\n\n별점 - 총 10점 중7\n\n가창력보다는 연기에 집중한 염정아의 좋은 연기와 얄미운 연기 최강자 류승룡. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'echo****'], ['18507576', '늑대사냥', '1', '\n늑대사냥\n\n별점 - 총 10점 중1\n\n오랜만에 본 정말 기계 쪽이나  의학 쪽 전개 전부 개똥같았던 영화 ?드라마도 이보단 나았겠다 억지 억지 이런 억지가 어디 또 있을까 오래전 부터 상업영화 관객은 돈벌이 수단이었지만 그 돈을 벌려면 관객들 수준을 압도하는 그런 영상을 만들어야지 눈가리고 아웅 돈만 벌면 그만이다 했던 시절은 이제 갔어요 이젠 감독 보다 관객이 더 하이 레벨이란 걸 알아야지 .... \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'hdc5****'], ['18507575', '에브리씽 에브리웨어 올 앳 원스', '10', '\n에브리씽 에브리웨어 올 앳 원스\n\n별점 - 총 10점 중10\n\n영화를 보고 장르 그자체에 신선함을 느낀건 정말 오랜만이다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'rose****'], ['18507574', '상견니', '10', '\n상견니\n\n별점 - 총 10점 중10\n\n리쯔웨이, 모쥔제, 황위쉬안 다 워아이니 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'kja6****'], ['18507573', '고고다이노 극장판: 얼음공룡의 비밀', '10', '\n고고다이노 극장판: 얼음공룡의 비밀\n\n별점 - 총 10점 중10\n\n영화 잘 봤습니다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'pook****'], ['18507572', '귀못', '8', '\n귀못\n\n별점 - 총 10점 중8\n\n오랜만의 한국적 공포영화라 반가웠다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'stev****'], ['18507571', '에브리씽 에브리웨어 올 앳 원스', '10', '\n에브리씽 에브리웨어 올 앳 원스\n\n별점 - 총 10점 중10\n\n인생을 살면서 본 모든 영화중에서 가장 미친 영화 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'kjh8****'], ['18507570', '프로메어', '10', '\n프로메어\n\n별점 - 총 10점 중10\n\n영화 잘 봤어요.. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'pook****'], ['18507569', '블랙 아담', '8', '\n블랙 아담\n\n별점 - 총 10점 중8\n\n무난하게 잘 봤습니다. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'hyun****'], ['18507568', '블랙 아담', '8', '\n블랙 아담\n\n별점 - 총 10점 중8\n\n이정도면 볼만함 꼬맹이 목소리때문에몰입 깨지는거 빼고는 좋았으 \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'sks0****'], ['18507567', '인생은 아름다워', '7', '\n인생은 아름다워\n\n별점 - 총 10점 중7\n\n가창력보다는 연기에 집중한 염정아의 좋은 연기와 얄미운 연기 최강자 류승룡. \n\t\t\t\n\t\t\t\n\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t\n\t\t\t\t신고\n', 'echo****'], ['18507576', '늑대사냥', '1', '\n늑대사냥\n\n별점 - 총 10점 중1\n\n오랜만에 본 정말 기계 쪽이나  의학 쪽 전개 전부 개똥같았던 영화 ?드라마도 이보단 나았겠다 억지 억지 이런 억지가 어디 또 있을까 오래전 부터 상업영화 관객은 돈벌이 수단이었지만 그 돈을 벌려면 관객들 수준을 압도하는 그런 영상을 만들어야지 눈가리고 ...

# %%
#총 리뷰 개수만 추출
txt3=txt2.replace('총', '').replace('개의 평점이 있습니다.', '')
print("<총",txt3,"건 수집완료 되었습니다.>")
print()
print("<네이버 리뷰 크롤링이 완료되었습니다.>")
print()
print("----------------------------------------------------------------")
